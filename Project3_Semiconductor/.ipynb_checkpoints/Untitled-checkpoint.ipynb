# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
import easyocr
import matplotlib.pyplot as plt
import cv2
import pandas as pd
from PIL import Image
from IPython.display import clear_output 
path_PT_1 = 'Vison_data/pattern_1'
path_PT_2 = 'Vison_data/pattern_2/pattern_2'
path_new_PT_1 = 'newData/pattern_1'
path_new_PT_2 = 'newData/pattern_2'

import numpy as np

'ready'
# Out:
# 'ready'

# %%
file_PT1 = np.array(os.listdir(path_PT_1))
file_PT1 = file_PT1[[ (i[-4:] == '.jpg') for i in file_PT1]]

file_PT2 = np.array(os.listdir(path_PT_2))
file_PT2 = file_PT2[[ (i[-4:] == '.jpg') for i in file_PT2]]
file_PT2
# Out:
# array(['pattern_2-1-1-1-D.jpg', 'pattern_2-1-1-10-D.jpg',
#        'pattern_2-1-1-11.jpg', 'pattern_2-1-1-12-D.jpg',
#        'pattern_2-1-1-13.jpg', 'pattern_2-1-1-14-D.jpg',
#        'pattern_2-1-1-15.jpg', 'pattern_2-1-1-16-D.jpg',
#        'pattern_2-1-1-17-D.jpg', 'pattern_2-1-1-18-D.jpg',
#        'pattern_2-1-1-19-D.jpg', 'pattern_2-1-1-2-D.jpg',
#        'pattern_2-1-1-20-D.jpg', 'pattern_2-1-1-21-D.jpg',
#        'pattern_2-1-1-22-D.jpg', 'pattern_2-1-1-23-D.jpg',
#        'pattern_2-1-1-24-D.jpg', 'pattern_2-1-1-25-D.jpg',
#        'pattern_2-1-1-26-D.jpg', 'pattern_2-1-1-27-D.jpg',
#        'pattern_2-1-1-28-D.jpg', 'pattern_2-1-1-29-D.jpg',
#        'pattern_2-1-1-3-D.jpg', 'pattern_2-1-1-30-D.jpg',
#        'pattern_2-1-1-31-D.jpg', 'pattern_2-1-1-32.jpg',
#        'pattern_2-1-1-33-D.jpg', 'pattern_2-1-1-34-D.jpg',
#        'pattern_2-1-1-35-D.jpg', 'pattern_2-1-1-36-D.jpg',
#        'pattern_2-1-1-37-D.jpg', 'pattern_2-1-1-38-D.jpg',
#        'pattern_2-1-1-39-D.jpg', 'pattern_2-1-1-4-D.jpg',
#        'pattern_2-1-1-40-D.jpg', 'pattern_2-1-1-41-D.jpg',
#        'pattern_2-1-1-42-D.jpg', 'pattern_2-1-1-43-D.jpg',
#        'pattern_2-1-1-44-D.jpg', 'pattern_2-1-1-45-D.jpg',
#        'pattern_2-1-1-46-D.jpg', 'pattern_2-1-1-47-D.jpg',
#        'pattern_2-1-1-48-D.jpg', 'pattern_2-1-1-49-D.jpg',
#        'pattern_2-1-1-5.jpg', 'pattern_2-1-1-50-D.jpg',
#        'pattern_2-1-1-51.jpg', 'pattern_2-1-1-52.jpg',
#        'pattern_2-1-1-53-D.jpg', 'pattern_2-1-1-54-D.jpg',
#        'pattern_2-1-1-55-D.jpg', 'pattern_2-1-1-56-D.jpg',
#        'pattern_2-1-1-57-D.jpg', 'pattern_2-1-1-58-D.jpg',
#        'pattern_2-1-1-59.jpg', 'pattern_2-1-1-6-D.jpg',
#        'pattern_2-1-1-60.jpg', 'pattern_2-1-1-61-D.jpg',
#        'pattern_2-1-1-62-D.jpg', 'pattern_2-1-1-63.jpg',
#        'pattern_2-1-1-64-D.jpg', 'pattern_2-1-1-65-D.jpg',
#        'pattern_2-1-1-66-D.jpg', 'pattern_2-1-1-67-D.jpg',
#        'pattern_2-1-1-68-D.jpg', 'pattern_2-1-1-69-D.jpg',
#        'pattern_2-1-1-7.jpg', 'pattern_2-1-1-70-D.jpg',
#        'pattern_2-1-1-71-D.jpg', 'pattern_2-1-1-72-D.jpg',
#        'pattern_2-1-1-73.jpg', 'pattern_2-1-1-74-D.jpg',
#        'pattern_2-1-1-75-D.jpg', 'pattern_2-1-1-76.jpg',
#        'pattern_2-1-1-77.jpg', 'pattern_2-1-1-78.jpg',
#        'pattern_2-1-1-79-D.jpg', 'pattern_2-1-1-8-D.jpg',
#        'pattern_2-1-1-80.jpg', 'pattern_2-1-1-81.jpg',
#        'pattern_2-1-1-82.jpg', 'pattern_2-1-1-83-D.jpg',
#        'pattern_2-1-1-84.jpg', 'pattern_2-1-1-85-D.jpg',
#        'pattern_2-1-1-86-D.jpg', 'pattern_2-1-1-87-D.jpg',
#        'pattern_2-1-1-88-D.jpg', 'pattern_2-1-1-89-D.jpg',
#        'pattern_2-1-1-9-D.jpg', 'pattern_2-1-1-90-D.jpg',
#        'pattern_2-1-1-91.jpg', 'pattern_2-1-1-92-D.jpg',
#        'pattern_2-1-2-1.jpg', 'pattern_2-1-2-10-D.jpg',
#        'pattern_2-1-2-11-D.jpg', 'pattern_2-1-2-12-D.jpg',
#        'pattern_2-1-2-13.jpg', 'pattern_2-1-2-14.jpg',
#        'pattern_2-1-2-2-D.jpg', 'pattern_2-1-2-3.jpg',
#        'pattern_2-1-2-4-D.jpg', 'pattern_2-1-2-5-D.jpg',
#        'pattern_2-1-2-6-D.jpg', 'pattern_2-1-2-7-D.jpg',
#        'pattern_2-1-2-8-D.jpg', 'pattern_2-1-2-9-D.jpg',
#        'pattern_2-1-3-1-D.jpg', 'pattern_2-1-3-10-D.jpg',
#        'pattern_2-1-3-11-D.jpg', 'pattern_2-1-3-12-D.jpg',
#        'pattern_2-1-3-13-D.jpg', 'pattern_2-1-3-14.jpg',
#        'pattern_2-1-3-15-D.jpg', 'pattern_2-1-3-16-D.jpg',
#        'pattern_2-1-3-17-D.jpg', 'pattern_2-1-3-2-D.jpg',
#        'pattern_2-1-3-3-D.jpg', 'pattern_2-1-3-4-D.jpg',
#        'pattern_2-1-3-5-D.jpg', 'pattern_2-1-3-6-D.jpg',
#        'pattern_2-1-3-7-D.jpg', 'pattern_2-1-3-8.jpg',
#        'pattern_2-1-3-9-D.jpg', 'pattern_2-1-4-1-D.jpg',
#        'pattern_2-1-4-10-D.jpg', 'pattern_2-1-4-11-D.jpg',
#        'pattern_2-1-4-12-D.jpg', 'pattern_2-1-4-13.jpg',
#        'pattern_2-1-4-14-D.jpg', 'pattern_2-1-4-15.jpg',
#        'pattern_2-1-4-16-D.jpg', 'pattern_2-1-4-2.jpg',
#        'pattern_2-1-4-3-D.jpg', 'pattern_2-1-4-4-D.jpg',
#        'pattern_2-1-4-5.jpg', 'pattern_2-1-4-6-D.jpg',
#        'pattern_2-1-4-7-D.jpg', 'pattern_2-1-4-8-D.jpg',
#        'pattern_2-1-4-9.jpg', 'pattern_2-1-5-1-D.jpg',
#        'pattern_2-1-5-10-D.jpg', 'pattern_2-1-5-11-D.jpg',
#        'pattern_2-1-5-12.jpg', 'pattern_2-1-5-13.jpg',
#        'pattern_2-1-5-14-D.jpg', 'pattern_2-1-5-15-D.jpg',
#        'pattern_2-1-5-16-D.jpg', 'pattern_2-1-5-17-D.jpg',
#        'pattern_2-1-5-2-D.jpg', 'pattern_2-1-5-3-D.jpg',
#        'pattern_2-1-5-4-D.jpg', 'pattern_2-1-5-5-D.jpg',
#        'pattern_2-1-5-6-D.jpg', 'pattern_2-1-5-7.jpg',
#        'pattern_2-1-5-8-D.jpg', 'pattern_2-1-5-9-D.jpg',
#        'pattern_2-1-6-1-D.jpg', 'pattern_2-1-6-10-D.jpg',
#        'pattern_2-1-6-11-D.jpg', 'pattern_2-1-6-12-D.jpg',
#        'pattern_2-1-6-13-D.jpg', 'pattern_2-1-6-2-D.jpg',
#        'pattern_2-1-6-3-D.jpg', 'pattern_2-1-6-4-D.jpg',
#        'pattern_2-1-6-5-D.jpg', 'pattern_2-1-6-6-D.jpg',
#        'pattern_2-1-6-7-D.jpg', 'pattern_2-1-6-8-D.jpg',
#        'pattern_2-1-6-9-D.jpg', 'pattern_2-1-7-1-D.jpg',
#        'pattern_2-1-7-10-D.jpg', 'pattern_2-1-7-11.jpg',
#        'pattern_2-1-7-12-D.jpg', 'pattern_2-1-7-2.jpg',
#        'pattern_2-1-7-3-D.jpg', 'pattern_2-1-7-4-D.jpg',
#        'pattern_2-1-7-5-D.jpg', 'pattern_2-1-7-6-D.jpg',
#        'pattern_2-1-7-7-D.jpg', 'pattern_2-1-7-8-D.jpg',
#        'pattern_2-1-7-9-D.jpg', 'pattern_2-1-8-1-D.jpg',
#        'pattern_2-1-8-10-D.jpg', 'pattern_2-1-8-11-D.jpg',
#        'pattern_2-1-8-12-D.jpg', 'pattern_2-1-8-2-D.jpg',
#        'pattern_2-1-8-3-D.jpg', 'pattern_2-1-8-4-D.jpg',
#        'pattern_2-1-8-5-D.jpg', 'pattern_2-1-8-6-D.jpg',
#        'pattern_2-1-8-7-D.jpg', 'pattern_2-1-8-8-D.jpg',
#        'pattern_2-1-8-9-D.jpg', 'pattern_2-1-9-1-D.jpg',
#        'pattern_2-1-9-2-D.jpg', 'pattern_2-1-9-3-D.jpg',
#        'pattern_2-1-9-4-D.jpg', 'pattern_2-1-9-5-D.jpg',
#        'pattern_2-1-9-6-D.jpg', 'pattern_2-1-9-7-D.jpg',
#        'pattern_2-1-9-8-D.jpg'], dtype='<U22')

# %%
file_PT1_NotD = file_PT1[[i [-5] != 'D' for i in file_PT1]]
file_PT1_NotD
# Out:
# array(['pattern_1-1-1-11.jpg', 'pattern_1-1-1-15.jpg',
#        'pattern_1-1-1-18.jpg', 'pattern_1-1-1-2.jpg',
#        'pattern_1-1-1-22.jpg', 'pattern_1-1-1-4.jpg',
#        'pattern_1-1-1-5.jpg', 'pattern_1-1-1-6.jpg',
#        'pattern_1-1-1-8.jpg', 'pattern_1-1-1-9.jpg',
#        'pattern_1-1-3-8.jpg', 'pattern_1-1-4-11.jpg',
#        'pattern_1-1-4-2.jpg', 'pattern_1-1-5-3.jpg',
#        'pattern_1-1-5-4.jpg', 'pattern_1-1-6-12.jpg',
#        'pattern_1-1-6-2.jpg', 'pattern_1-1-7-12.jpg',
#        'pattern_1-1-7-3.jpg', 'pattern_1-1-8-11.jpg',
#        'pattern_1-1-8-4.jpg', 'pattern_1-1-9-10.jpg'], dtype='<U22')

# %%
file_PT1_NotD = cv2.imread(os.path.join(path_PT_1,file_PT1[0]),cv2.IMREAD_GRAYSCALE)
plt.imshow(img_test,cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 file_PT1_NotD = cv2.imread(os.path.join(path_PT_1,file_PT1[0]),cv2.IMREAD_GRAYSCALE)
# ----> 2 plt.imshow(img_test,cmap='gray')
#
# NameError: name 'img_test' is not defined

# %%
plt.imshow(img_test_B,cmap='gray')

# %%
def canny_closed(img,th_1 = 100,th_2 =250,kernel_val=1):

    edged = cv2.Canny(img, th_1, th_2)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (kernel_val,kernel_val))
    closed = cv2.morphologyEx(edged, cv2.MORPH_CLOSE, kernel)
    
    return   edged , closed

# %%
plt.imshow(img_test)

# %%
img_test = cv2.imread(os.path.join(path_PT_1,file_PT1[25]),cv2.IMREAD_GRAYSCALE)

img_test_B = cv2.GaussianBlur(img_test,(3,3),3)
_, edg = canny_closed(img_test_B,th_1=40,th_2=30,kernel_val=1)

k = cv2.getStructuringElement(cv2.MORPH_RECT, (5,5))
erosion = cv2.erode(edg, k)
dilate = cv2.dilate(edg, k)

img_open = cv2.morphologyEx(edg,cv2.MORPH_OPEN,k)

f,ax = plt.subplots(2,2)
f.set_size_inches(15,15)

ax[0,0].imshow(img_test,cmap='gray')
ax[0,1].imshow(img_test_B,cmap='gray')
ax[1,0].imshow(edg,cmap='gray')
ax[1,1].imshow(dilate,cmap='gray')

cnt, labels = cv2.connectedComponents(dilate)

print(cnt)
# Out:
# 80

# %%
FC = cv2.cvtColor(cv2.imread(os.path.join(path_PT_1,file_PT1[0])),cv2.COLOR_RGB2BGR)
FC_HSV = cv2.cvtColor(FC,cv2.COLOR_BGR2HSV)

f,ax = plt.subplots(1,3)
f.set_size_inches(15,15)
ax[0].imshow(FC_HSV[:,:,0],cmap='gray')
ax[1].imshow(FC_HSV[:,:,1],cmap='gray')
ax[2].imshow(FC_HSV[:,:,2],cmap='gray')
cnt, labels = cv2.connectedComponents(edg)

# %%
index = 60


origin = cv2.imread(os.path.join(path_PT_1,file_PT1[index]))
origin = cv2.cvtColor(origin,cv2.COLOR_BGR2RGB)


a = cv2.cvtColor(origin,cv2.COLOR_BGR2GRAY)
a = cv2.bilateralFilter(a,-1,3,3)
b = cv2.cvtColor(origin,cv2.COLOR_BGR2HSV)
b = cv2.blur(b,(199,199),50)
c = 255 - (a - b[:,:,2])

_, d = cv2.threshold(c,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# _, d = canny_closed(d,th_1=50,th_2=100,kernel_val=5)


# k = cv2.getStructuringElement(cv2.MORPH_RECT, (5,5))
# d = cv2.morphologyEx(d,cv2.MORPH_CLOSE,k)







f,ax = plt.subplots(2,2)
f.set_size_inches(15,15)
ax[0,0].imshow(a,cmap='gray')
ax[0,0].set_title('gray_bilateralFilter')
ax[1,0].imshow(b,cmap='gray')
ax[1,0].set_title('light ')
ax[0,1].imshow(c,cmap='gray')
ax[0,1].set_title('gray_bilateralFilter -light')
ax[1,1].imshow(d,cmap='gray')
ax[1,1].set_title('binary (origin - light)')
plt.show()



f,ax = plt.subplots(1,2)
f.set_size_inches(15,15)

ax[0].imshow(origin,cmap='gray')
ax[0].set_title('origin')
ax[1].imshow(d,cmap='gray')
ax[1].set_title('result ')
# Out:
# Text(0.5, 1.0, 'result ')

# %%
def THRESH_BINARY(img):
#     origin = cv2.imread(os.path.join(path_PT_1,file_PT1[index]))
    origin = img.copy()
    origin = cv2.cvtColor(origin,cv2.COLOR_BGR2RGB)


    a = cv2.cvtColor(origin,cv2.COLOR_BGR2GRAY)
    a = cv2.bilateralFilter(a,-1,3,3)
    b = cv2.cvtColor(origin,cv2.COLOR_BGR2HSV)
    b = cv2.blur(b,(199,199),50)
    c = 255 - (a - b[:,:,2])

    _, d = cv2.threshold(c,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

    return d

# %%
def Line_Connect(img):

# %%
index = 60


origin = cv2.imread(os.path.join(path_PT_1,file_PT1[index]))
origin = cv2.cvtColor(origin,cv2.COLOR_BGR2RGB)
a = THRESH_BINARY(origin)

plt.figure(figsize=(9,9))
plt.imshow(a,cmap='gray')

# %%
plt.figure(figsize=(7,7))
plt.imshow(a[0:150,0:150],cmap='gray')

# %%
plt.figure(figsize=(7,7))
# plt.imshow(a[130:150,40:60],cmap='gray')
plt.imshow(point(a,(240,1065),55),cmap='gray')

# %%
point(a,(140,50),21).shape
# Out:
# (21, 21)

# %%
def point(img,grid,ksize=5):
    return img[(grid[0]-(int(ksize/2))):(grid[0]+(int(ksize/2)))+1,(grid[1]-(int(ksize/2))):(grid[1]+(int(ksize/2)))+1]

# %%
for i,fname in enumerate(file_PT1):
    print(str(i)+' / '+ str(len(file_PT1)))
    clear_output(wait=True)
    ti = cv2.imread(os.path.join(path_PT_1,fname))
    newti = THRESH_BINARY(ti)
    cv2.imwrite(os.path.join(path_new_PT_1,fname),newti)

clear_output(wait=True)
print('completed')
# Out:
# completed

# %%
for i,fname in enumerate(file_PT2):
    print(str(i)+' / '+ str(len(file_PT2)))
    clear_output(wait=True)
    ti = cv2.imread(os.path.join(path_PT_2,fname))
    newti = THRESH_BINARY(ti)
    cv2.imwrite(os.path.join(path_new_PT_2,fname),newti)

clear_output(wait=True)
print('completed')
# Out:
# completed

# %%
cnt, labels = cv2.connectedComponents(edg)

display(pd.DataFrame(np.array(labels).reshape(-1)).value_counts())

IT = np.zeros(labels.shape)
for i in range(cnt):
    # 레이블이 같은 영역에 랜덤한 색상 적용 ---②
    IT[labels==i] = np.random.randint(0,255)


plt.imshow(IT)
# Out:
# 0     1372797
# 7       19837
# 6       18918
# 1       14748
# 8        8612
# 26       2524
# 17       1893
# 25        304
# 3          27
# 2          25
# 14         24
# 18         22
# 23         22
# 11         21
# 5          19
# 19         19
# 27         19
# 15         18
# 20         18
# 24         18
# 4          18
# 16         17
# 12         17
# 22         16
# 10         16
# 13         14
# 9          11
# 21          6
# dtype: int64
